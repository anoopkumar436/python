# %%
# Handling Inappropriate Data
# The only baseline to understand whether the data in the given column is appropriate or not is , "DOMAIN KNOWLEDGE"

# %%
# Guidelines
# ==================================================================================================================
#
# 1. Idenify the type of the data for each column ----- Numerical (Continous and Discrete), Categorical, Ordinal
#
# 2. Check and remove all duplicate records from the DataFrame
#
# 3. Check and remove all duplicate columns from the DataFrame
#
# 4. If your column is a Numerical Column, perform the following steps:
#
#    - If your data is continous, check with reference to the domain whether the following parameters are valid or not:
#      1. Negative Numbers are allowed or not
#      2. Positive Numbers are allowed or not
#      3. Decimals are allowed, or Integers are expected 
#   If 1. and 2. is found, delete that specfic column entry
#   If 3. is found, perform typecasting
#
#    - If your data is discrete, check with reference to the domain whether the following parameters are valid or not:
#      1. Negative Numbers are allowed or not
#      2. Positive Numbers are allowed or not
#      3. Decimals are allowed, or Integers are expected 
#      4. Check whether the number falls in a specified range or not defined by the domain.
#   If 1.2. & 4. ffound, delete that specific column entry
#   If 3. is found, perform typecasting
#
#
# 5. If your columns are Categorical Columns, perform the following steps:
#      1. Get the unique values of the column
#      2. Handle the data which has Spelling errors, Case Errors (lowercase, uppercase) --- (NLP , Dictionary Search)
#      3. Check whether the groups/categories shown in the unique values match the domain spec. If there exists any unusual
#         entry against the domain, delete the specific entry
#
# 6. If your columns are Ordinal Columns, perform the following steps:
#      1. Get the unique values of the column
#      2. Handle the data which has Spelling errors, Case Errors (lowercase, uppercase) --- (NLP , Dictionary Search)
#      3. Check whether the groups/categories shown in the unique values match the domain spec. If there exists any unusual
#         entry against the domain, delete the specific entry
#      4. Check the mathematical weightage of each unique value . Ensure it match the domain spec.
#      5. If no mathematical weightage is introduced in the column, ensure you define the same as per the domain standards.
#
# 7. Dealing with date columns (Time Series Analysis)
#   1. Convert date column into datetime datatype
#   2. Ensure your row index is replaced with the above date columns
#
# All of the above rules must be backed up with Domain Knowledge, If required add more rules for your project!!

# %%
import numpy as np
import pandas as pd

# %% [raw]
# #load data from source.
# data = pd.read_csv('datasetExample.csv')
# data

# %%
# 1. Idenify the type of the data for each column 
#  Numerical(Continous and Discrete ), Categorical, Ordinal
#
#============================================================================================================
data.info()
#
#=============================================================================================================
#  int64 ----- Numerical( Continous and Discrete)
#  object ---- text ( Categorical and Ordinal)
#
#==============================================================================================================
#
#CustomerID         11 non-null int64 ------> NUmerical (Continous)
#Age_Group          11 non-null object -----> Categorical
#Rating(1-5)        11 non-null int64 ------> Numerical (Discrete) (1,2,3,4,5)
#Hotel              11 non-null object -----> Categorical
#FoodPreference     11 non-null object -----> Categorical
#Bill               11 non-null int64 ------> NUmerical (Continous)
#NoOfPax            11 non-null int64 ------> Numerical (Discrete) (1-20)
#EstimatedSalary    11 non-null int64 ------> NUmerical (Continous)
#Age_Group.1        11 non-null object -----> Categorical ------------------------> Duplicate Column Detected
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       11 non-null     int64
#  1   Age_Group        11 non-null     object
#  2   Rating(1-5)      11 non-null     int64
#  3   Hotel            11 non-null     object
#  4   FoodPreference   11 non-null     object
#  5   Bill             11 non-null     int64
#  6   NoOfPax          11 non-null     int64
#  7   EstimatedSalary  11 non-null     int64
#  8   Age_Group.1      11 non-null     object
# dtypes: int64(5), object(4)
# memory usage: 920.0+ bytes

# %%
# 2. Check and remove all duplicate records from the DataFrame
data.drop_duplicates(inplace=True)
data
# Out:
#     CustomerID Age_Group  Rating(1-5)      Hotel FoodPreference  Bill  \
# 0            1     20-25            4       Ibis            veg  1300
# 1            2     30-35            5  LemonTree        Non-Veg  2000
# 2            3     25-30            6     RedFox            Veg  1322
# 3            4     20-25           -1  LemonTree            Veg  1234
# 4            5       35+            3       Ibis     Vegetarian   989
# 5            6       35+            3       Ibys        Non-Veg  1909
# 6            7       35+            4     RedFox     Vegetarian  1000
# 7            8     20-25            7  LemonTree            Veg  2999
# 8            9     25-30            2       Ibis        Non-Veg  3456
# 10          10     30-35            5     RedFox        non-Veg -6755
#
#     NoOfPax  EstimatedSalary Age_Group.1
# 0         2            40000       20-25
# 1         3            59000       30-35
# 2         2            30000       25-30
# 3         2           120000       20-25
# 4         2            45000         35+
# 5         2           122220         35+
# 6        -1            21122         35+
# 7       -10           345673       20-25
# 8         3           -99999       25-30
# 10        4            87777       30-35

# %%
#Reset the index
indexCol = np.array(list(range(len(data))))
data.set_index(indexCol, inplace=True)
data
# Out:
#    CustomerID Age_Group  Rating(1-5)      Hotel FoodPreference  Bill  NoOfPax  \
# 0           1     20-25            4       Ibis            veg  1300        2
# 1           2     30-35            5  LemonTree        Non-Veg  2000        3
# 2           3     25-30            6     RedFox            Veg  1322        2
# 3           4     20-25           -1  LemonTree            Veg  1234        2
# 4           5       35+            3       Ibis     Vegetarian   989        2
# 5           6       35+            3       Ibys        Non-Veg  1909        2
# 6           7       35+            4     RedFox     Vegetarian  1000       -1
# 7           8     20-25            7  LemonTree            Veg  2999      -10
# 8           9     25-30            2       Ibis        Non-Veg  3456        3
# 9          10     30-35            5     RedFox        non-Veg -6755        4
#
#    EstimatedSalary Age_Group.1
# 0            40000       20-25
# 1            59000       30-35
# 2            30000       25-30
# 3           120000       20-25
# 4            45000         35+
# 5           122220         35+
# 6            21122         35+
# 7           345673       20-25
# 8           -99999       25-30
# 9            87777       30-35

# %%
# 3. Check and remove all duplicate columns from the DataFrame
data.drop(['Age_Group.1'], axis=1,  inplace=True)

# %%
data
# Out:
#    CustomerID Age_Group  Rating(1-5)      Hotel FoodPreference  Bill  NoOfPax  \
# 0           1     20-25            4       Ibis            veg  1300        2
# 1           2     30-35            5  LemonTree        Non-Veg  2000        3
# 2           3     25-30            6     RedFox            Veg  1322        2
# 3           4     20-25           -1  LemonTree            Veg  1234        2
# 4           5       35+            3       Ibis     Vegetarian   989        2
# 5           6       35+            3       Ibys        Non-Veg  1909        2
# 6           7       35+            4     RedFox     Vegetarian  1000       -1
# 7           8     20-25            7  LemonTree            Veg  2999      -10
# 8           9     25-30            2       Ibis        Non-Veg  3456        3
# 9          10     30-35            5     RedFox        non-Veg -6755        4
#
#    EstimatedSalary
# 0            40000
# 1            59000
# 2            30000
# 3           120000
# 4            45000
# 5           122220
# 6            21122
# 7           345673
# 8           -99999
# 9            87777

# %%
# 4. If your column is a Numerical Column, perform the following steps:
#
#    - If your data is continous, check with reference to the domain whether the following parameters are valid or not:
#      1. Negative Numbers are allowed or not
#      2. Positive Numbers are allowed or not
#      3. Decimals are allowed, or Integers are expected 
#   If 1. and 2. is found, delete that specfic column entry
#   If 3. is found, perform typecasting
#

#CustomerID         11 non-null int64 ------> NUmerical (Continous)
#Bill               11 non-null int64 ------> NUmerical (Continous)
#EstimatedSalary    11 non-null int64 ------> NUmerical (Continous)

# %%
# check nagative value exist in numerical values in data. one by one 
#       1. Negative Numbers are allowed or not
data[data.CustomerID < 0]
# Out:
# Empty DataFrame
# Columns: [CustomerID, Age_Group, Rating(1-5), Hotel, FoodPreference, Bill, NoOfPax, EstimatedSalary]
# Index: []

# %%
#Found one negative bill value which is against the domain policy
data[data.Bill <0]
# Out:
#    CustomerID Age_Group  Rating(1-5)   Hotel FoodPreference  Bill  NoOfPax  \
# 9          10     30-35            5  RedFox        non-Veg -6755        4
#
#    EstimatedSalary
# 9            87777

# %%
#Replace with NaN
data.Bill.loc[data.Bill < 0 ] = np.nan
data
# Out:
# C:\Users\ANOOP\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
#    CustomerID Age_Group  Rating(1-5)      Hotel FoodPreference    Bill  \
# 0           1     20-25            4       Ibis            veg  1300.0
# 1           2     30-35            5  LemonTree        Non-Veg  2000.0
# 2           3     25-30            6     RedFox            Veg  1322.0
# 3           4     20-25           -1  LemonTree            Veg  1234.0
# 4           5       35+            3       Ibis     Vegetarian   989.0
# 5           6       35+            3       Ibys        Non-Veg  1909.0
# 6           7       35+            4     RedFox     Vegetarian  1000.0
# 7           8     20-25            7  LemonTree            Veg  2999.0
# 8           9     25-30            2       Ibis        Non-Veg  3456.0
# 9          10     30-35            5     RedFox        non-Veg     NaN
#
#    NoOfPax  EstimatedSalary
# 0        2            40000
# 1        3            59000
# 2        2            30000
# 3        2           120000
# 4        2            45000
# 5        2           122220
# 6       -1            21122
# 7      -10           345673
# 8        3           -99999
# 9        4            87777

# %%
type(data.loc[9,'Bill'])
# Out:
# numpy.float64

# %%
type(np.float64('NaN'))
# Out:
# numpy.float64

# %%
#Found one negative bill value which is against the domain policy
data[data.EstimatedSalary < 0]
# Out:
#    CustomerID Age_Group  Rating(1-5) Hotel FoodPreference    Bill  NoOfPax  \
# 8           9     25-30            2  Ibis        Non-Veg  3456.0        3
#
#    EstimatedSalary
# 8           -99999

# %%
#Replace with NaN
data.loc[8,'EstimatedSalary'] = np.float64('NaN')

# %%
data
# Out:
#    CustomerID Age_Group  Rating(1-5)      Hotel FoodPreference    Bill  \
# 0           1     20-25            4       Ibis            veg  1300.0
# 1           2     30-35            5  LemonTree        Non-Veg  2000.0
# 2           3     25-30            6     RedFox            Veg  1322.0
# 3           4     20-25           -1  LemonTree            Veg  1234.0
# 4           5       35+            3       Ibis     Vegetarian   989.0
# 5           6       35+            3       Ibys        Non-Veg  1909.0
# 6           7       35+            4     RedFox     Vegetarian  1000.0
# 7           8     20-25            7  LemonTree            Veg  2999.0
# 8           9     25-30            2       Ibis        Non-Veg  3456.0
# 9          10     30-35            5     RedFox        non-Veg     NaN
#
#    NoOfPax  EstimatedSalary
# 0        2          40000.0
# 1        3          59000.0
# 2        2          30000.0
# 3        2         120000.0
# 4        2          45000.0
# 5        2         122220.0
# 6       -1          21122.0
# 7      -10         345673.0
# 8        3              NaN
# 9        4          87777.0

# %%
type(data.loc[8,'EstimatedSalary'])
# Out:
# numpy.float64

# %%
#    - If your data is discrete, check with reference to the domain whether the following parameters are valid or not:
#      1. Negative Numbers are allowed or not
#      2. Positive Numbers are allowed or not
#      3. Decimals are allowed, or Integers are expected 
#      4. Check whether the number falls in a specified range or not defined by the domain.
#   If 1.2. & 4. ffound, delete that specific column entry
#   If 3. is found, perform typecasting
#

#Rating(1-5)        11 non-null int64 ------> Numerical (Discrete) (1,2,3,4,5)
#NoOfPax            11 non-null int64 ------> Numerical (Discrete) (1-20)

# %%
# we get a row Nagetive value in Rating column.
data[data["Rating(1-5)"]< 0]
# Out:
#    CustomerID Age_Group  Rating(1-5)      Hotel FoodPreference    Bill  \
# 3           4     20-25           -1  LemonTree            Veg  1234.0
#
#    NoOfPax  EstimatedSalary
# 3        2         120000.0

# %%
# Replace nagitve vaule into nan.
data.loc[3,'Rating(1-5)'] = np.float64("NaN")

# %%
type(np.float64("NaN"))
# Out:
# numpy.float64

# %%
data
# Out:
#    CustomerID Age_Group  Rating(1-5)      Hotel FoodPreference    Bill  \
# 0           1     20-25          4.0       Ibis            veg  1300.0
# 1           2     30-35          5.0  LemonTree        Non-Veg  2000.0
# 2           3     25-30          6.0     RedFox            Veg  1322.0
# 3           4     20-25          NaN  LemonTree            Veg  1234.0
# 4           5       35+          3.0       Ibis     Vegetarian   989.0
# 5           6       35+          3.0       Ibys        Non-Veg  1909.0
# 6           7       35+          4.0     RedFox     Vegetarian  1000.0
# 7           8     20-25          7.0  LemonTree            Veg  2999.0
# 8           9     25-30          2.0       Ibis        Non-Veg  3456.0
# 9          10     30-35          5.0     RedFox        non-Veg     NaN
#
#    NoOfPax  EstimatedSalary
# 0        2          40000.0
# 1        3          59000.0
# 2        2          30000.0
# 3        2         120000.0
# 4        2          45000.0
# 5        2         122220.0
# 6       -1          21122.0
# 7      -10         345673.0
# 8        3              NaN
# 9        4          87777.0

# %%
data[data["Rating(1-5)"]> 5]
# Out:
#    CustomerID Age_Group  Rating(1-5)      Hotel FoodPreference    Bill  \
# 2           3     25-30          6.0     RedFox            Veg  1322.0
# 7           8     20-25          7.0  LemonTree            Veg  2999.0
#
#    NoOfPax  EstimatedSalary
# 2        2          30000.0
# 7      -10         345673.0

# %%
data.loc[[2,7],'Rating(1-5)'] = np.float64("NaN")

# %%
data
# Out:
#    CustomerID Age_Group  Rating(1-5)      Hotel FoodPreference    Bill  \
# 0           1     20-25          4.0       Ibis            veg  1300.0
# 1           2     30-35          5.0  LemonTree        Non-Veg  2000.0
# 2           3     25-30          NaN     RedFox            Veg  1322.0
# 3           4     20-25          NaN  LemonTree            Veg  1234.0
# 4           5       35+          3.0       Ibis     Vegetarian   989.0
# 5           6       35+          3.0       Ibys        Non-Veg  1909.0
# 6           7       35+          4.0     RedFox     Vegetarian  1000.0
# 7           8     20-25          NaN  LemonTree            Veg  2999.0
# 8           9     25-30          2.0       Ibis        Non-Veg  3456.0
# 9          10     30-35          5.0     RedFox        non-Veg     NaN
#
#    NoOfPax  EstimatedSalary
# 0        2          40000.0
# 1        3          59000.0
# 2        2          30000.0
# 3        2         120000.0
# 4        2          45000.0
# 5        2         122220.0
# 6       -1          21122.0
# 7      -10         345673.0
# 8        3              NaN
# 9        4          87777.0

# %%
data[ (data.NoOfPax < 0) | (data.NoOfPax >20)]
# Out:
#    CustomerID Age_Group  Rating(1-5)      Hotel FoodPreference    Bill  \
# 6           7       35+          4.0     RedFox     Vegetarian  1000.0
# 7           8     20-25          NaN  LemonTree            Veg  2999.0
#
#    NoOfPax  EstimatedSalary
# 6       -1          21122.0
# 7      -10         345673.0

# %%
data.loc[[6,7],"NoOfPax"] = np.float64("NaN")

# %%
data
# Out:
#    CustomerID Age_Group  Rating(1-5)      Hotel FoodPreference    Bill  \
# 0           1     20-25          4.0       Ibis            veg  1300.0
# 1           2     30-35          5.0  LemonTree        Non-Veg  2000.0
# 2           3     25-30          NaN     RedFox            Veg  1322.0
# 3           4     20-25          NaN  LemonTree            Veg  1234.0
# 4           5       35+          3.0       Ibis     Vegetarian   989.0
# 5           6       35+          3.0       Ibys        Non-Veg  1909.0
# 6           7       35+          4.0     RedFox     Vegetarian  1000.0
# 7           8     20-25          NaN  LemonTree            Veg  2999.0
# 8           9     25-30          2.0       Ibis        Non-Veg  3456.0
# 9          10     30-35          5.0     RedFox        non-Veg     NaN
#
#    NoOfPax  EstimatedSalary
# 0      2.0          40000.0
# 1      3.0          59000.0
# 2      2.0          30000.0
# 3      2.0         120000.0
# 4      2.0          45000.0
# 5      2.0         122220.0
# 6      NaN          21122.0
# 7      NaN         345673.0
# 8      3.0              NaN
# 9      4.0          87777.0

# %%
# 5. If your columns are Categorical Columns, perform the following steps:
#      1. Get the unique values of the column
#      2. Handle the data which has Spelling errors, Case Errors (lowercase, uppercase) --- (NLP , Dictionary Search)
#      3. Check whether the groups/categories shown in the unique values match the domain spec. If there exists any unusual
#         entry against the domain, delete the specific entry

#Age_Group          11 non-null object -----> Categorical
#Hotel              11 non-null object -----> Categorical
#FoodPreference     11 non-null object -----> Categorical

# %%
data.Age_Group.unique()
# Out:
# array(['20-25', '30-35', '25-30', '35+'], dtype=object)

# %%
data.Hotel.unique()
# Out:
# array(['Ibis', 'LemonTree', 'RedFox', 'Ibys'], dtype=object)

# %%
# in Hotel column has some speling error like "Ibis" and "Ibys"
# we will convert "Ibys" into "Ibis" 

data.Hotel.replace(["Ibys","Ibis"],"Ibis", inplace=True)
data
# Out:
#    CustomerID Age_Group  Rating(1-5)      Hotel FoodPreference    Bill  \
# 0           1     20-25          4.0       Ibis            veg  1300.0
# 1           2     30-35          5.0  LemonTree        Non-Veg  2000.0
# 2           3     25-30          NaN     RedFox            Veg  1322.0
# 3           4     20-25          NaN  LemonTree            Veg  1234.0
# 4           5       35+          3.0       Ibis     Vegetarian   989.0
# 5           6       35+          3.0       Ibis        Non-Veg  1909.0
# 6           7       35+          4.0     RedFox     Vegetarian  1000.0
# 7           8     20-25          NaN  LemonTree            Veg  2999.0
# 8           9     25-30          2.0       Ibis        Non-Veg  3456.0
# 9          10     30-35          5.0     RedFox        non-Veg     NaN
#
#    NoOfPax  EstimatedSalary
# 0      2.0          40000.0
# 1      3.0          59000.0
# 2      2.0          30000.0
# 3      2.0         120000.0
# 4      2.0          45000.0
# 5      2.0         122220.0
# 6      NaN          21122.0
# 7      NaN         345673.0
# 8      3.0              NaN
# 9      4.0          87777.0

# %%
data.FoodPreference.unique()
# Out:
# array(['veg', 'Non-Veg', 'Veg', 'Vegetarian', 'non-Veg'], dtype=object)

# %%
# FoodPreference column has find some speling error.
#  "Veg", "vag", "Vegetarin" into "Veg"
#  "Non-Veg", "non-Veg" into "Non-Veg"

# %%
data.FoodPreference.replace(['veg','Vegetarian'],'Veg', inplace=True)

# %%
data
# Out:
#    CustomerID Age_Group  Rating(1-5)      Hotel FoodPreference    Bill  \
# 0           1     20-25          4.0       Ibis            Veg  1300.0
# 1           2     30-35          5.0  LemonTree        Non-Veg  2000.0
# 2           3     25-30          NaN     RedFox            Veg  1322.0
# 3           4     20-25          NaN  LemonTree            Veg  1234.0
# 4           5       35+          3.0       Ibis            Veg   989.0
# 5           6       35+          3.0       Ibis        Non-Veg  1909.0
# 6           7       35+          4.0     RedFox            Veg  1000.0
# 7           8     20-25          NaN  LemonTree            Veg  2999.0
# 8           9     25-30          2.0       Ibis        Non-Veg  3456.0
# 9          10     30-35          5.0     RedFox        non-Veg     NaN
#
#    NoOfPax  EstimatedSalary
# 0      2.0          40000.0
# 1      3.0          59000.0
# 2      2.0          30000.0
# 3      2.0         120000.0
# 4      2.0          45000.0
# 5      2.0         122220.0
# 6      NaN          21122.0
# 7      NaN         345673.0
# 8      3.0              NaN
# 9      4.0          87777.0

# %%
data.FoodPreference.replace(['non-Veg'],'Non-Veg', inplace=True)
data
# Out:
#    CustomerID Age_Group  Rating(1-5)      Hotel FoodPreference    Bill  \
# 0           1     20-25          4.0       Ibis            Veg  1300.0
# 1           2     30-35          5.0  LemonTree        Non-Veg  2000.0
# 2           3     25-30          NaN     RedFox            Veg  1322.0
# 3           4     20-25          NaN  LemonTree            Veg  1234.0
# 4           5       35+          3.0       Ibis            Veg   989.0
# 5           6       35+          3.0       Ibis        Non-Veg  1909.0
# 6           7       35+          4.0     RedFox            Veg  1000.0
# 7           8     20-25          NaN  LemonTree            Veg  2999.0
# 8           9     25-30          2.0       Ibis        Non-Veg  3456.0
# 9          10     30-35          5.0     RedFox        Non-Veg     NaN
#
#    NoOfPax  EstimatedSalary
# 0      2.0          40000.0
# 1      3.0          59000.0
# 2      2.0          30000.0
# 3      2.0         120000.0
# 4      2.0          45000.0
# 5      2.0         122220.0
# 6      NaN          21122.0
# 7      NaN         345673.0
# 8      3.0              NaN
# 9      4.0          87777.0

# %%
data.to_csv("data.csv",mode='a', header=True)

# %% [markdown]
# # compelete first setup handling inappropriate data.
